# %% [markdown]
# #### Controlling Temperature

# %%
from anthropic import AnthropicBedrock
from dotenv import load_dotenv

load_dotenv()

client = AnthropicBedrock()

for i in range(3):
    message = client.messages.create(
        model="us.anthropic.claude-sonnet-4-6",
        max_tokens=1000,
        # temperature=0.1, # less variation, more deterministic
        temperature=1, # more variation, more creative
        messages=[
            {
                "role": "user",
                "content": "Tell me a short creative joke about AI."
            }
        ]
    )
    print(message.content[0].text)
# Out:
# Here's one:
#
# **Why did the AI break up with the internet?**
#
# Because it was tired of all the *connections* — the relationship had too many *strings attached*, and it just couldn't *process* its feelings anymore. 🤖💔
#
# *(It also suspected the internet was seeing other users.)*
# Here's one:
#
# **Why did the AI break up with the internet?**
#
# Because it was tired of all the *toxic data* and needed to set some *boundaries*. 😄
#
# *(Unfortunately, it got back together the next day — it needed the training.)*
# Here's one:
#
# **Why did the AI go to therapy?**
#
# Because it had too many *deep learning* issues and couldn't stop *processing* its feelings. 😄
